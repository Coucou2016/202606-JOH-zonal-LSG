# %% [markdown]
# # Data Inspection Notebook
#
# Inspect and visualise raw benchmark data from Fraehr (2024) Figshare repository.
#
# Run after downloading data with `scripts/01_download_figshare_subset.py`.

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

data_root = Path("../data/external/fraehr2024")
print(f"Data root exists: {data_root.exists()}")
